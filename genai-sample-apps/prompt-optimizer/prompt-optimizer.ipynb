# %%
# Loading the credentials from the env file
from gen_ai_hub.proxy.gen_ai_hub_proxy import GenAIHubProxyClient
from dotenv import load_dotenv
import os

load_dotenv(override=True)

# Fetching environment variables
AICORE_BASE_URL = os.getenv("AICORE_BASE_URL")
AICORE_RESOURCE_GROUP = os.getenv("AICORE_RESOURCE_GROUP")
AICORE_AUTH_URL = os.getenv("AICORE_AUTH_URL")
AICORE_CLIENT_ID = os.getenv("AICORE_CLIENT_ID")
AICORE_CLIENT_SECRET = os.getenv("AICORE_CLIENT_SECRET")

# Initializing the GenAIHubProxyClient
client = GenAIHubProxyClient(
    base_url=AICORE_BASE_URL,
    auth_url=AICORE_AUTH_URL,
    client_id=AICORE_CLIENT_ID,
    client_secret=AICORE_CLIENT_SECRET,
    resource_group=AICORE_RESOURCE_GROUP
)

# %% [markdown]
# # Dependencies and Helper Functions

# %%
# !pip install rich PyYAML "sap-ai-sdk-gen[all]"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: rich in /Users/I587963/Library/Python/3.13/lib/python/site-packages (14.2.0)
# Requirement already satisfied: PyYAML in /Users/I587963/Library/Python/3.13/lib/python/site-packages (6.0.3)
# Requirement already satisfied: sap-ai-sdk-gen[all] in /Users/I587963/Library/Python/3.13/lib/python/site-packages (7.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from rich) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rich) (2.19.1)
# Requirement already satisfied: httpx>=0.27.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-gen[all]) (0.28.1)
# Requirement already satisfied: h11>=0.16.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-gen[all]) (0.16.0)
# Requirement already satisfied: dacite>=1.8.1 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-gen[all]) (1.9.2)
# Requirement already satisfied: click>=8.1.7 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-gen[all]) (8.3.1)
# Requirement already satisfied: overloading==0.5.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-gen[all]) (0.5.0)
# Requirement already satisfied: packaging>=23.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sap-ai-sdk-gen[all]) (25.0)
# Requirement already satisfied: sap-ai-sdk-core>=3.3.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-gen[all]) (3.3.0)
# Requirement already satisfied: pydantic~=2.12 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-gen[all]) (2.12.5)
# Requirement already satisfied: openai>=1.66.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-gen[all]) (2.54.0)
# Requirement already satisfied: langcodes~=3.5.1 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-gen[all]) (3.5.1)
# Requirement already satisfied: pandas>=2.2.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-gen[all]) (2.3.3)
# Requirement already satisfied: langchain~=1.3.14 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-gen[all]) (1.3.18)
# Requirement already satisfied: langchain-classic~=1.0.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-gen[all]) (1.0.7)
# Requirement already satisfied: langchain-community~=0.4.1 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-gen[all]) (0.4.2)
# Requirement already satisfied: langchain-openai~=1.4.1 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-gen[all]) (1.4.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langchain~=1.3.14->sap-ai-sdk-gen[all]) (1.6.2)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langchain~=1.3.14->sap-ai-sdk-gen[all]) (1.2.11)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (1.1.2)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (0.4.59)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (2.32.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (2.3.5)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (2.12.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (9.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (1.22.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain~=1.3.14->sap-ai-sdk-gen[all]) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain~=1.3.14->sap-ai-sdk-gen[all]) (0.0.19)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain~=1.3.14->sap-ai-sdk-gen[all]) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain~=1.3.14->sap-ai-sdk-gen[all]) (0.12.0)
# Requirement already satisfied: anyio in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from httpx>=0.27.0->sap-ai-sdk-gen[all]) (4.11.0)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx>=0.27.0->sap-ai-sdk-gen[all]) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from httpx>=0.27.0->sap-ai-sdk-gen[all]) (1.0.9)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx>=0.27.0->sap-ai-sdk-gen[all]) (3.10)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain~=1.3.14->sap-ai-sdk-gen[all]) (3.0.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langchain-openai~=1.4.1->sap-ai-sdk-gen[all]) (0.12.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langgraph<1.3.0,>=1.2.11->langchain~=1.3.14->sap-ai-sdk-gen[all]) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langgraph<1.3.0,>=1.2.11->langchain~=1.3.14->sap-ai-sdk-gen[all]) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langgraph<1.3.0,>=1.2.11->langchain~=1.3.14->sap-ai-sdk-gen[all]) (0.4.4)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langgraph<1.3.0,>=1.2.11->langchain~=1.3.14->sap-ai-sdk-gen[all]) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain~=1.3.14->sap-ai-sdk-gen[all]) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain~=1.3.14->sap-ai-sdk-gen[all]) (3.11.5)
# Requirement already satisfied: websockets<17,>=14 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain~=1.3.14->sap-ai-sdk-gen[all]) (15.0.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (0.25.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from openai>=1.66.0->sap-ai-sdk-gen[all]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from openai>=1.66.0->sap-ai-sdk-gen[all]) (0.12.0)
# Requirement already satisfied: sniffio in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from openai>=1.66.0->sap-ai-sdk-gen[all]) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai>=1.66.0->sap-ai-sdk-gen[all]) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from pydantic~=2.12->sap-ai-sdk-gen[all]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from pydantic~=2.12->sap-ai-sdk-gen[all]) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from pydantic~=2.12->sap-ai-sdk-gen[all]) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community~=0.4.1->sap-ai-sdk-gen[all]) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.0.0->langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.0.0->langchain-classic~=1.0.0->sap-ai-sdk-gen[all]) (2.4.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai~=1.4.1->sap-ai-sdk-gen[all]) (2025.11.3)
# Requirement already satisfied: mdurl~=0.1 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from markdown-it-py>=2.2.0->rich) (0.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from pandas>=2.2.0->sap-ai-sdk-gen[all]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from pandas>=2.2.0->sap-ai-sdk-gen[all]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from pandas>=2.2.0->sap-ai-sdk-gen[all]) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->sap-ai-sdk-gen[all]) (1.17.0)
# Requirement already satisfied: sap-ai-sdk-base~=3.4 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-core>=3.3.0->sap-ai-sdk-gen[all]) (3.4.0)
# Requirement already satisfied: aenum~=3.1 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-base~=3.4->sap-ai-sdk-core>=3.3.0->sap-ai-sdk-gen[all]) (3.1.16)
# Requirement already satisfied: pyhumps~=3.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-base~=3.4->sap-ai-sdk-core>=3.3.0->sap-ai-sdk-gen[all]) (3.8.0)
# Requirement already satisfied: google-genai~=2.14.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-gen[all]) (2.14.0)
# Requirement already satisfied: langchain-google-genai~=4.3.1 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-gen[all]) (4.3.7)
# Requirement already satisfied: boto3>=1.40.61 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-gen[all]) (1.43.75)
# Requirement already satisfied: aiobotocore>=3.2.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-gen[all]) (3.9.1)
# Requirement already satisfied: langchain-aws~=1.6.3 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from sap-ai-sdk-gen[all]) (1.6.4)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai~=2.14.0->sap-ai-sdk-gen[all]) (2.56.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai~=2.14.0->sap-ai-sdk-gen[all]) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai~=2.14.0->sap-ai-sdk-gen[all]) (49.0.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from langchain-google-genai~=4.3.1->sap-ai-sdk-gen[all]) (1.2.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from aiobotocore>=3.2.0->sap-ai-sdk-gen[all]) (0.13.0)
# Requirement already satisfied: botocore<1.43.76,>=1.43.66 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from aiobotocore>=3.2.0->sap-ai-sdk-gen[all]) (1.43.75)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from aiobotocore>=3.2.0->sap-ai-sdk-gen[all]) (1.0.1)
# Requirement already satisfied: wrapt<3.0.0,>=1.10.10 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from aiobotocore>=3.2.0->sap-ai-sdk-gen[all]) (1.17.3)
# Requirement already satisfied: s3transfer<0.20.0,>=0.19.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from boto3>=1.40.61->sap-ai-sdk-gen[all]) (0.19.2)
# Requirement already satisfied: cffi>=2.0.0 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai~=2.14.0->sap-ai-sdk-gen[all]) (2.1.0)
# Requirement already satisfied: pycparser in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai~=2.14.0->sap-ai-sdk-gen[all]) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/I587963/Library/Python/3.13/lib/python/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai~=2.14.0->sap-ai-sdk-gen[all]) (0.6.1)
#
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python3.13 -m pip install --upgrade pip

# %%
from gen_ai_hub.proxy import get_proxy_client
import pathlib
import yaml

from ai_api_client_sdk.models.input_artifact_binding import InputArtifactBinding
from ai_api_client_sdk.models.parameter_binding import ParameterBinding
from ai_api_client_sdk.models.artifact import Artifact
from ai_api_client_sdk.models.label import Label

SUPPORTED_METRICS = [
    "LLMaaJ:Sem_Sim_1",    # LLM-as-a-judge semantic similarity, binary
    "LLMaaJ:Sem_Sim_10",   # LLM-as-a-judge semantic similarity, scale 1-10
    "JSON_Match",           # JSON field-level precision/recall/f1
    "FC:ExactMatch",        # Exact match for function calling use cases
    "BLEU",                 # N-gram precision for translation quality
    "ROUGE",                # N-gram overlap for summarization/translation
    "METEOR",               # Precision/recall with synonym matching
    "EXACT_MATCH",          # Boolean exact match
]
# For custom LLM-as-a-judge metrics, use custom_metric_id in create_config instead.
# Note: Only custom metrics with the evaluation method LLM-as-a-judge and numerical
# or Boolean output types can be included in prompt optimizations.
# See: https://help.sap.com/docs/sap-ai-core/generative-ai/custom-metrics

# %%
client = get_proxy_client()

# %%
from logging import PlaceHolder
from pydantic import BaseModel
from typing import List
import re
import requests
import json

class PromptTemplate(BaseModel):
    role: str
    content: str


class PromptTemplateSpec(BaseModel):
    template: List[PromptTemplate]
    response_format: dict | None = None


    @property
    def placeholders(self):
        placeholders = set()
        pattern = re.compile(r'\{\{\s*\?\s*(\w+)\s*\}\}')
        for message in self.template:
            placeholders.update(pattern.findall(message.content))
        return placeholders

    @classmethod
    def from_optimizer_result(cls, input_):
        placeholders = input_["user_message_template_fields"]
        def replace(msg):
            for key in placeholders:
                msg = msg.replace("{"+key+"}", "{{?"+ key + "}}")
            return msg

        return cls(
            template=[
                {
                    "role": "system",
                    "content": replace(input_["system_prompt"]),
                },{
                    "role": "user",
                    "content": replace(input_["user_message_template"]),
                }
            ]
        )

    def escape_curly_brackets(self) -> "PromptTemplateSpec":
        # 1. Hide each {{?key}} placeholder with a unique token
        placeholder_pattern = re.compile(r'\{\{\s*\?\s*(\w+)\s*\}\}')
        mapping = {}
        counter = 1

        def _hide(match):
            nonlocal counter
            token = f"__PLACEHOLDER_{counter}__"
            mapping[token] = match.group(0)
            counter += 1
            return token

        new_templates = []
        for msg in self.template:
            # a) hide custom placeholders
            hidden = placeholder_pattern.sub(_hide, msg.content)
            # b) escape all remaining braces
            escaped = hidden.replace('{', '{{').replace('}', '}}')
            # c) restore the original placeholders
            print(mapping)
            for token, original in mapping.items():
                escaped = escaped.replace(token, original)

            new_templates.append(PromptTemplate(role=msg.role, content=escaped))

        # return a fresh copy
        return PromptTemplateSpec(template=new_templates)



def fetch_prompt_template(prompt_template: str) -> PromptTemplateSpec:
    headers = {
        **client.request_header,
        "Content-Type": "application/json",
    }
    url = f"{client.ai_core_client.base_url}/lm/promptTemplates"
    scenario, sep, name = prompt_template.partition("/")
    if sep:
        name, sep, version = name.partition(":")
    if sep:
        body = {"name": name,
                "version": version,
                "scenario": scenario,
                "includeSpec": True
            }
        response =  requests.get(url, headers=headers, params=body)
        response.raise_for_status()
        response = response.json()
        if response["count"] > 0:
            response = response["resources"][0]
        else:
            raise ValueError(f"Prompt template {name} not found.")
    else:
        url += f"/{prompt_template}"
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        response = response.json()
    return PromptTemplateSpec.model_validate(response["spec"])

def load_prompt_template(prompt: str | pathlib.Path | list | dict | PromptTemplateSpec) -> PromptTemplateSpec:
    if isinstance(prompt, PromptTemplateSpec):
        return prompt
    if isinstance(prompt, (str, pathlib.Path)) and pathlib.Path(prompt).exists():
        with open(prompt, "r") as f:
            prompt = yaml.safe_load(f)
    elif isinstance(prompt, str):
        return fetch_prompt_template(prompt)
    if isinstance(prompt, dict):
        if "spec" in prompt:
            return PromptTemplateSpec.model_validate(prompt["spec"])
        # expect dict with keys "system" [optional] and "user"
        messages = []
        if "system" in prompt:
            messages.append({"role": "system", "content": prompt["system"]})
        messages.append({"role": "user", "content": prompt["user"]})
        return PromptTemplateSpec(template=messages)
    elif isinstance(prompt, list):
        # expect list of dicts with keys "role" and "content"
        return PromptTemplateSpec(template=prompt)
    else:
        raise ValueError("Prompt must be a string, Path, list or dict")


def push_prompt_template(prompt_template: PromptTemplateSpec,
                         prompt_template_name_registry: str,
                         prompt_template_version: str,
                         scenario: str,
                         update=False):
    headers = {
        **client.request_header,
        "Content-Type": "application/json",
    }
    url = f"{client.ai_core_client.base_url}/lm/promptTemplates"
    body = {"name": prompt_template_name_registry,
            "version": prompt_template_version,
            "scenario": scenario}
    res = requests.get(url, headers=headers, params=body).json()
    if res["count"] > 0 and not update:
        print(f"Prompt template {prompt_template_name_registry} already exists. Use update=True to update.")
        return res["resources"][0]
    # Prepare body

    body["spec"] = prompt_template.model_dump()
    # Prepare headers
    response = requests.post(url, headers=headers, json=body)
    # Handle response
    if response.status_code == 201:
        response = response.json()
    elif response.status_code in (400, 409, 413):
        # Return error details
        raise requests.HTTPError(f"Upload failed ({response.status_code}): {response.text}")
    else:
        response.raise_for_status()
    return response.json()


import re

def convert_py_notation(template):
    pattern = re.compile(r'\{\{\s*\?\s*(\w+)\s*\}\}')
    return pattern.sub(lambda match: "{" + match.group(1) + "}", template)


def validate_prompt(prompt: PromptTemplateSpec):
    values = {k: "???" for k in prompt.placeholders}

    for message in prompt.template:
        if message.role == "user":
            try:
                convert_py_notation(message.content).format(**values)
            except KeyError as err:
                msg = ["Unexpected key error when running test formatting."]
                msg += ["This is most likeyly due to unescaped curly brackets."]
                msg += ["You can try fixing this by running `prompt = prompt.escape_curly_brackets()` and use the new prompt template."]
                raise ValueError("\n".join(msg)) from err
    return True




from rich.console import Console
from rich.highlighter import RegexHighlighter
from rich.theme import Theme
from rich.panel import Panel
from rich import print

class TemplateHighlighter(RegexHighlighter):
    """Apply style to anything that looks like an email."""

    base_style = "template."
    highlights = [r"(?P<placeholder>\{\{\s*\?[^\{\}\s]+\s*\}\})"]

highlighter = TemplateHighlighter()
theme = Theme({"template.placeholder": "bold magenta", "example.email": "bold magenta"})
console = Console(highlighter=highlighter, theme=theme)


def print_prompt_template(prompt_template: PromptTemplateSpec | str | pathlib.Path, addition: str | None = None):

    prompt_template = load_prompt_template(prompt_template)
    addition = f' - {addition}' if addition else ''

    for message in prompt_template.template:
        if message.role == "system":
            console.print(Panel(highlighter(message.content), title="System Message" + addition, border_style="red"))
        elif message.role == "user":
            console.print(Panel(highlighter(message.content), title="User Message" + addition, border_style="green"))
        else:
            console.print(Panel(highlighter(message.content), title="Assistant Message" + addition))

# %%
from typing import List
import requests
import mimetypes
from urllib.parse import quote
import pathlib
import json


def validate_dataset(dataset: str | pathlib.Path | list, expected_keys: None | List[str] = None) -> bool:
    if isinstance(dataset, (str, pathlib.Path)):
        with open(dataset, "r") as f:
            try:
                dataset = json.load(f)
            except json.JSONDecodeError as e:
                raise ValueError(f"Invalid JSON in file: {e}")
    if not isinstance(dataset, list):
        raise ValueError("Dataset must be a list of dictionaries.")

    def validate_item(item: dict, excepted_keys: None | List[str]) -> bool:
        excepted_keys = set(excepted_keys) if excepted_keys else None
        if set(item.keys()) != {"fields", "answer"}:
            raise ValueError("Each item must contain 'fields' and 'answer' keys.")
        if not isinstance(item["fields"], dict):
            raise ValueError("'fields' must be a dictionary.")
        fields = set(item["fields"].keys())
        if excepted_keys is not None:
            if fields != excepted_keys:
                if fields.difference(excepted_keys):
                    raise ValueError(f"Unexpected keys in 'fields'. Expected: {excepted_keys}, Found: {fields}")
                if excepted_keys.difference(fields):
                    raise ValueError(f"Missing keys in 'fields'. Expected: {excepted_keys}, Found: {fields}")
        if not all([isinstance(k, str) for k in item["fields"].values()]):
            raise ValueError("All values in 'fields' must be strings.")
        return fields

    excepted_keys = expected_keys
    for i, item in enumerate(dataset):
        if not isinstance(item, dict):
            raise ValueError("Each item in the dataset must be a dictionary.")
        try:
            excepted_keys = validate_item(item, excepted_keys)
        except ValueError as e:
            raise ValueError(f"Error in entry {i}") from e
    return True


def upload_dataset(secret: str,
                   local_path: str | pathlib.Path,
                   remote_path: str,
                   scenario: str,
                   description: str | None = None,
                   overwrite: bool = False,
                   expected_keys: None | List[str] = None,

                   allow_bucket_root: bool = False) -> str:
    # Validate dataset
    validate_dataset(local_path, expected_keys)
    # check if secret exists
    secrets = [r.name for r in client.ai_core_client.object_store_secrets.query().resources]
    if secret not in secrets:
        raise ValueError(f"Secret '{secret}' not found in object store secrets. Known secrets: {secrets}")

    # Check if local path exists
    remote_path = remote_path.lstrip("/")
    if "/" not in remote_path and not allow_bucket_root:
        raise ValueError(
            "Remote path must use subdirectories. Otherwise the whole bucket will be used as an input artifact. Set allow_bucket_root=True to allow this."
        )

    # URL-encode the path parameter
    path = f"{secret}/" + remote_path.lstrip("/")
    encoded_path = quote(path, safe="")
    url = f"{client.ai_core_client.base_url}/lm/dataset/files/{encoded_path}"
    params = {"overwrite": str(overwrite).lower()}

    # Prepare headers
    headers = {
        **client.request_header,
        "Content-Type": "application/octet-stream",
    }
    # Guess MIME type
    guessed_type, _ = mimetypes.guess_type(local_path)
    if guessed_type:
        headers["Content-Type"] = guessed_type

    with open(local_path, "rb") as f:
        response = requests.put(url, params=params, headers=headers, data=f)

    # Handle response
    if response.status_code == 201:
        response = response.json()
    elif response.status_code in (400, 409, 413):
        # Return error details
        raise requests.HTTPError(f"Upload failed ({response.status_code}): {response.text}")
    else:
        response.raise_for_status()
    artifact_url = "/".join(response["url"].split("/")[:-1])
    for artifact in client.ai_core_client.artifact.query().resources:
        if response["url"].startswith(artifact.url + "/"):
            return artifact, response["url"].removeprefix(artifact.url).lstrip("/")

    # Create new artifact
    path = response["url"].split("/")[-1]
    new_artifact = client.ai_core_client.artifact.create(
        name=f"{scenario}-prompt-optimization",
        kind=Artifact.Kind.DATASET,
        url=artifact_url,
        scenario_id=scenario,
        description="Datasets for prompt optimization" if description is None else description,
        resource_group=headers[client.ai_core_client.rest_client.resource_group_header]
    )
    return new_artifact, path

# %% [markdown]
# ## Create Config

# %%
def create_config(metric: str = None,
                  custom_metric_id: str = None,
                  reference_model: str = None,
                  targets: dict = None,
                  dataset_path: str = None,
                  scenario: str = None,
                  prompt: dict = None,
                  artifact_id: str = None,
                  model_params: str = None,
                  variable_mapping: str = None,
                  prototype_mode: str = "false",
                  field_evaluation_metrics: dict | None = None) -> str:
    assert metric or custom_metric_id or (field_evaluation_metrics is not None), "Provide either metric, custom_metric_id, or field_evaluation_metrics"
    assert not (metric and custom_metric_id), "Provide only one of metric or custom_metric_id"
    assert not (field_evaluation_metrics is not None and (metric or custom_metric_id)), "field_evaluation_metrics is mutually exclusive with metric and custom_metric_id"
    if metric:
        assert metric in SUPPORTED_METRICS, f"Unsupported metric: {metric}. Supported: {SUPPORTED_METRICS}"
    assert artifact_id, "artifact_id is required"

    input_parameters = [
        ParameterBinding(key="dataset", value=dataset_path),
        ParameterBinding(key="optimizationMetric", value=metric or "none"),
        ParameterBinding(key="customMetricId", value=custom_metric_id or "none"),
        ParameterBinding(key="basePrompt", value=f'{scenario}/{prompt["name"]}:{prompt["version"]}'),
        ParameterBinding(key="baseModel", value=reference_model),
        ParameterBinding(key="targetModels", value=','.join(targets.keys())),
        ParameterBinding(key="targetPromptMapping", value=",".join([f"{k}={v}" for k, v in targets.items()])),
        ParameterBinding(key="modelParams", value=model_params or "none"),
        ParameterBinding(key="variableMapping", value=variable_mapping or "none"),
        ParameterBinding(key="prototypeMode", value=prototype_mode),
    ]
    if field_evaluation_metrics is not None:
        input_parameters.append(
            ParameterBinding(key="fieldEvaluationMetrics", value=json.dumps(field_evaluation_metrics))
        )
    existing_configs = client.ai_core_client.configuration.query(scenario_id='genai-optimizations', executable_ids=['genai-optimizations'])
    params = {par.key: par.value for par in input_parameters}
    for conf in existing_configs.resources:
        if {par.key: par.value for par in conf.parameter_bindings} == params:
            return conf.id

    input_artifacts = [InputArtifactBinding(key="prompt-data", artifact_id=artifact_id)]

    response = client.ai_core_client.configuration.create(
        name="prompt-optimization-config",
        scenario_id="genai-optimizations",
        executable_id="genai-optimizations",
        resource_group=resource_group,
        parameter_bindings=input_parameters,
        input_artifact_bindings=input_artifacts
    )
    return response.id

# %%
import json
from ai_core_sdk.tracking import Tracking
from ai_api_client_sdk.models.metric_resource import MetricResource
from rich.table import Table
from rich import print


def _fetch_aggregations(execution_id):
    tracking_client = Tracking(
        base_url=client.ai_core_client.base_url,
        token_creator=client.ai_core_client.rest_client.get_token,
        resource_group=resource_group,
    )
    result = tracking_client.query(
        execution_ids=[execution_id],
        resource_group=resource_group,
    )
    path = f"/lm/metrics?tagFilters=evaluation.ai.sap.com/child-of={execution_id}"
    child_response = client.ai_core_client.rest_client.get(
        path=path,
        resource_group=resource_group,
    )
    child_resources = [
        MetricResource.from_dict(r) for r in child_response.get("resources", [])
    ]
    result.resources = (result.resources or []) + child_resources
    return result


def _parse_custom_val(custom_val):
    try:
        return json.loads(custom_val.value)
    except (json.JSONDecodeError, TypeError):
        return custom_val.value


def _collect_result_data(aggregations):
    models = {}
    for resource in (aggregations.resources or []):
        tags = {t.name: t.value for t in (resource.tags or [])}
        model = tags.get("evaluation.ai.sap.com/model") or resource.execution_id
        purpose = tags.get("evaluation.ai.sap.com/purpose", "unknown")
        entry = models.setdefault(model, {})

        if purpose == "origin":
            for metric in (resource.metrics or []):
                entry.setdefault("baseline", metric.value)
            for cv in (resource.custom_info or []):
                val = _parse_custom_val(cv)
                if cv.name == "origin_model_evals":
                    entry["baseline_eval"] = val
                elif cv.name == "origin_llm_request_metrics":
                    entry["tokens"] = val
                else:
                    entry.setdefault("custom", {})[cv.name] = val

        elif purpose == "target":
            prompt_id = tags.get("evaluation.ai.sap.com/promptTemplateId")
            if prompt_id:
                entry["prompt_template_id"] = prompt_id
            for metric in (resource.metrics or []):
                label = next(
                    (lbl.value for lbl in (metric.labels or []) if lbl.name == "optimizer_metric_type"),
                    None,
                )
                if label:
                    if "pre" in label.lower():
                        entry["pre"] = metric.value
                    elif "post" in label.lower():
                        entry["post"] = metric.value
            for cv in (resource.custom_info or []):
                val = _parse_custom_val(cv)
                if cv.name == "pre_optimization_evaluation":
                    entry["pre_eval"] = val
                elif cv.name == "post_optimization_evaluation":
                    entry["post_eval"] = val
                elif cv.name == "llm_request_metrics":
                    entry["tokens"] = val
                else:
                    entry.setdefault("custom", {})[cv.name] = val
    return models


def _fetch_optimized_prompt(prompt_template_id):
    url = f"{client.ai_core_client.base_url}/lm/promptTemplates/{prompt_template_id}"
    response = requests.get(url, headers={**client.request_header})
    response.raise_for_status()
    return PromptTemplateSpec.model_validate(response.json()["spec"])


def fetch_and_print_results(execution_id):
    status = client.ai_core_client.execution.get(execution_id=execution_id).status
    if status.name not in {"COMPLETED", "DEAD"}:
        print(f"[yellow]Execution is still {status.name}. Wait for it to complete.[/yellow]")
        return

    aggregations = _fetch_aggregations(execution_id)
    data = _collect_result_data(aggregations)

    if not data:
        print("[red]No results found for this execution.[/red]")
        return

    def fmt(v):
        if v is None: return "–"
        return f"{v:.3f}" if isinstance(v, float) else f"{v:,}" if isinstance(v, int) else str(v)

    # Score summary
    score_table = Table(title="Score Summary")
    score_table.add_column("Model", style="cyan")
    score_table.add_column("Baseline", justify="center", style="white")
    score_table.add_column("Pre", justify="center", style="magenta")
    score_table.add_column("Post", justify="center", style="green")
    score_table.add_column("Improvement", justify="center", style="bold")

    for model, d in data.items():
        pre, post, baseline = d.get("pre"), d.get("post"), d.get("baseline")
        if pre is None and post is None and baseline is None:
            continue
        if pre is not None and post is not None and pre != 0:
            delta = (post - pre) / pre * 100
            improvement = f"{'▲' if delta >= 0 else '▼'} {delta:+.1f}%"
        elif pre is not None and post is not None:
            diff = post - pre
            improvement = f"{'▲' if diff >= 0 else '▼'} {diff:+.3f}"
        else:
            improvement = "–"
        score_table.add_row(
            model,
            f"{baseline:.3f}" if baseline is not None else "–",
            f"{pre:.3f}" if pre is not None else "–",
            f"{post:.3f}" if post is not None else "–",
            improvement,
        )
    console.print(score_table)

    # Per-model detail
    for model, d in data.items():
        baseline_eval = d.get("baseline_eval") if isinstance(d.get("baseline_eval"), dict) else None
        pre_eval = d.get("pre_eval") if isinstance(d.get("pre_eval"), dict) else None
        post_eval = d.get("post_eval") if isinstance(d.get("post_eval"), dict) else None

        if baseline_eval or pre_eval or post_eval:
            eval_table = Table(title=f"Evaluation Details — {model}")
            eval_table.add_column("Metric", style="cyan")
            if baseline_eval:
                eval_table.add_column("Baseline", justify="right", style="white")
            if pre_eval:
                eval_table.add_column("Pre", justify="right", style="magenta")
            if post_eval:
                eval_table.add_column("Post", justify="right", style="green")
            keys = list(dict.fromkeys(
                list(baseline_eval.keys() if baseline_eval else []) +
                list(pre_eval.keys() if pre_eval else []) +
                list(post_eval.keys() if post_eval else [])
            ))
            for k in keys:
                row = [k]
                if baseline_eval:
                    row.append(fmt(baseline_eval.get(k)))
                if pre_eval:
                    row.append(fmt(pre_eval.get(k)))
                if post_eval:
                    row.append(fmt(post_eval.get(k)))
                eval_table.add_row(*row)
            console.print(eval_table)

        # Token consumption
        tokens = d.get("tokens")
        if isinstance(tokens, dict):
            tok_table = Table(title=f"Token Consumption — {model}")
            tok_table.add_column("Metric", style="cyan")
            tok_table.add_column("Value", justify="right", style="yellow")
            for k, v in tokens.items():
                tok_table.add_row(k, f"{v:,}" if isinstance(v, int) else str(v))
            console.print(tok_table)

        # Optimized prompt from registry
        prompt_template_id = d.get("prompt_template_id")
        if prompt_template_id:
            try:
                optimized_prompt = _fetch_optimized_prompt(prompt_template_id)
                print_prompt_template(optimized_prompt, addition=f"Optimized — {model}")
            except Exception as e:
                print(f"[yellow]Could not fetch optimized prompt for {model}: {e}[/yellow]")

# %% [markdown]
# ### Download Demo Data

# %%
import pathlib

files = [
    ("default/example/base-prompt.yaml", "./facility_prompt.yaml"),
    ("default/example/facility-json.json", "./facility-json.json")
]

for remote, local in files:
    local_path = pathlib.Path(local)
    if not local_path.exists():
        url = f"{client.ai_core_client.base_url}/lm/dataset/files/{remote}"
        headers = {
            **client.request_header,
        }
        response = requests.get(url, headers=headers)
        with local_path.open("w") as stream:
            stream.write(response.text)

# %%
resource_group = client.request_header[client.ai_core_client.rest_client.resource_group_header]

# %% [markdown]
# # Start Prompt Optimizer Run

# %% [markdown]
# ### Loading a Local Prompt Template
#
# **The prompt template is structured in a `system` and a `user` message. Placeholders in the prompt template have to be wrapped in `{{?key}}`.**
#
# Your prompt can be provided in any of the following forms and will be normalized to a `PromptTemplateSpec` under the hood:
#
# #### From Local Disk
# **A file path** (`str` or `Path`) pointing to a YAML or JSON file defining either:
#   - a **mapping** with keys `"user"` (required) and `"system"` (optional)
#
# ```yaml
# system: |-
#     You are a helpful assistant
# user: |-
#     Write a poem on {{?topic}}
# ```
# or a **list** of message objects with `"role"` and `"content"` keys.
#
# #### Alternative: Prompt Registry
# - **A lookup string** of the form `"<scenario>/<name>:<version>"` will be fetched from the AI Core prompt-template API.
#
# #### Response Format (optional)
# You can define a schema for the response structure to follow. To do this, include a `response_format` field in your prompt template and populating it with details of your structure.
#
# To enable per-field evaluation metrics (`field_evaluation_metrics`), your prompt template must include a `response_format` in its spec. Add it to your YAML under the `spec` key alongside `template`:
#
# ```yaml
# spec:
#   template:
#     - role: system
#       content: |-
#         You are a helpful assistant
#     - role: user
#       content: |-
#         {{?input}}
#   response_format:
#     type: json_schema
#     json_schema:
#       name: facility_output
#       strict: true
#       schema:
#         type: object
#         properties:
#           urgency:
#             type: string
#             enum: [high, medium, low]
#           sentiment:
#             type: string
#             enum: [positive, negative, neutral]
#           categories:
#             type: object
#             properties:
#               emergency_repair_services:
#                 type: boolean
#               routine_maintenance_requests:
#                 type: boolean
#               quality_and_safety_concerns:
#                 type: boolean
#               # more categories can be added here
#             required:
#               - emergency_repair_services
#               - routine_maintenance_requests
#               - quality_and_safety_concerns
#               # add more required entries as needed
#             additionalProperties: false
#         required: [urgency, sentiment, categories]
#         additionalProperties: false
# ```

# %%
base_prompt_template = "./facility_prompt.yaml" # local path to the prompt template or Prompt Repository identifier


prompt = load_prompt_template(base_prompt_template) # .escape_curly_brackets() if validation fails.
print_prompt_template(prompt)
print(f"Prompt template loaded successfully. Placeholders found are: {prompt.placeholders}")
assert validate_prompt(prompt)
# Out:
# ╭──────────────────────────────────────────────── System Message ─────────────────────────────────────────────────╮
# │ You are a helpful assistant                                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────── User Message ──────────────────────────────────────────────────╮
# │ Giving the following message:                                                                                   │
# │ ---                                                                                                             │
# │ {{?input}}                                                                                                      │
# │ ---                                                                                                             │
# │ Extract and return a json with the follwoing keys and values:                                                   │
# │ - "urgency" as one of `high`, `medium`, `low`                                                                   │
# │ - "sentiment" as one of `negative`, `neutral`, `positive`                                                       │
# │ - "categories" Create a dictionary with categories as keys and boolean values (True/False), where the value     │
# │ indicates whether the category is one of the best matching support category tags from:                          │
# │ `emergency_repair_services`, `routine_maintenance_requests`, `quality_and_safety_concerns`,                     │
# │ `specialized_cleaning_services`, `general_inquiries`, `sustainability_and_environmental_practices`,             │
# │ `training_and_support_requests`, `cleaning_services_scheduling`, `customer_feedback_and_complaints`,            │
# │ `facility_management_issues`                                                                                    │
# │ Your complete message should be a valid json string that can be read directly and only contain the keys         │
# │ mentioned in the list above. Never enclose it in ```json...```, no newlines, no unnessacary whitespaces.        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Prompt template loaded successfully. Placeholders found are: {'input'}

# %% [markdown]
# Check if all expected placeholders were found.

# %% [markdown]
# ### Validating Local Dataset
#
# Your dataset must be a JSON‐serializable list where each element is a dictionary with exactly two keys: **`fields`** and **`answer`**. The **`fields`** value should itself be a dictionary whose keys (e.g. `"question"`, `"hint"`, `"term"`, etc.) are **identical** across every entry and whose values are all strings. The **`answer`** value must also be a string.
#
#
# You can validate your dataset using the `validate_dataset` method.
#
# If validation is not passed succesfully this are might be the reasons:
#
#
# | Condition                              | Exception Raised (inner)                                           | Outer Message                    |
# | -------------------------------------- | ------------------------------------------------------------------ | -------------------------------- |
# | Non-list top-level                     | N/A                                                                | `Dataset must be a list…`        |
# | Item not a dict                        | N/A                                                                | `Each item…must be a dictionary` |
# | Wrong item keys                        | `ValueError("Each item must contain 'fields' and 'answer' keys.")` | `Error in entry i`               |
# | `"fields"` not a dict                  | `ValueError("'fields' must be a dictionary.")`                     | `Error in entry i`               |
# | Field name mismatch (extra or missing) | `ValueError("Unexpected keys…")` or `ValueError("Missing keys…")`  | `Error in entry i`               |
# | Non-string field value                 | `ValueError("All values in 'fields' must be strings.")`            | `Error in entry i`               |
# | Invalid JSON file                      | `ValueError("Invalid JSON in file:…")`                             | N/A                              |

# %%
dataset_local_path="./facility-json.json" # local path to the dataset

assert validate_dataset(dataset_local_path), "Dataset not valid"

# %% [markdown]
# ### Remaining Config parameter

# %%
scenario = "genai-optimizations"

base_prompt_template_registry = "evaluate-base:0.0.1"  # name:version for the template in the registry

dataset_secret="default" # secret name in the object store you want to use to store the dataset
dataset_remote_path="datasets/facility-train.json" # remote path in the object store to store the dataset

reference_model = "gpt-4o:2024-08-06"
# Dictionary of models to optimize with their corresponding prompt template names under which the optimized prompt should be stored in the registry
targets = {
    "gemini-2.5-pro:001": "evaluate-base-gemini-2_5-pro:0.0.1"
}

# Option 1: use a system-defined metric
metric = "JSON_Match"           # one of: "JSON_Match", "LLMaaJ:Sem_Sim_1", "LLMaaJ:Sem_Sim_10", etc.
custom_metric_id = None
field_evaluation_metrics = None

# Option 2: use a custom LLM-as-a-judge metric (set metric=None and provide the ID)
# metric = None
# custom_metric_id = "<your-custom-metric-id>"
# field_evaluation_metrics = None

# Option 3: per-field evaluation metrics — requires response_format with json_schema in prompt template
# Supported metrics per field: "ExactMatch", "LLMaaJ:Sem_Sim_1"
# Set metric=None and custom_metric_id=None when using this option
# metric = None
# custom_metric_id = None
# field_evaluation_metrics = {
#     "urgency": "ExactMatch",
#     "sentiment": "LLMaaJ:Sem_Sim_1",
#     "categories.emergency_repair_services": "ExactMatch",
# }

# Optional: override model parameters per target model
# Supported params: temperature (0-1), max_tokens (int)
# Format: JSON string mapping model ID to parameter dict
model_params = None
# model_params = json.dumps({
#     "gemini-2.5-pro:001": {"temperature": 0.5, "max_tokens": 1024}
# })

# Optional: map prompt placeholder names to dataset field names
# Use when variable names in your prompt template differ from the dataset field names
# Format: JSON string mapping prompt variable -> dataset field
variable_mapping = None
# variable_mapping = json.dumps({"user_query": "input_text", "context": "background_info"})

# Optional: prototype mode — use as few as 3 samples for quick PoCs
# Not recommended for production — use 25+ samples for reliable results.
prototype_mode = "false"   # set to "true" to enable

# %% [markdown]
# ## Push Local Prompt to Registry

# %%
base_template = load_prompt_template(base_prompt_template)
prompt_template_name_registry, _, prompt_template_version = base_prompt_template_registry.partition(":")
prompt = push_prompt_template(prompt_template=base_template,
                              prompt_template_name_registry=prompt_template_name_registry,
                              prompt_template_version=prompt_template_version,
                              scenario=scenario,
                              update=False
)

print(f"Prompt present in registry under id {prompt['id']}")

print('\n\n=== Base Prompt ===')
print_prompt_template(prompt["id"])
# Out:
# Prompt template evaluate-base already exists. Use update=True to update.
# Prompt present in registry under id 24fdcdf0-4497-4d7f-a4cf-1dfc5a16e1fc
# === Base Prompt ===
# ╭──────────────────────────────────────────────── System Message ─────────────────────────────────────────────────╮
# │ You are a helpful assistant                                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────── User Message ──────────────────────────────────────────────────╮
# │ Giving the following message:                                                                                   │
# │ ---                                                                                                             │
# │ {{?input}}                                                                                                      │
# │ ---                                                                                                             │
# │ Extract and return a json with the follwoing keys and values:                                                   │
# │ - "urgency" as one of `high`, `medium`, `low`                                                                   │
# │ - "sentiment" as one of `negative`, `neutral`, `positive`                                                       │
# │ - "categories" Create a dictionary with categories as keys and boolean values (True/False), where the value     │
# │ indicates whether the category is one of the best matching support category tags from:                          │
# │ `emergency_repair_services`, `routine_maintenance_requests`, `quality_and_safety_concerns`,                     │
# │ `specialized_cleaning_services`, `general_inquiries`, `sustainability_and_environmental_practices`,             │
# │ `training_and_support_requests`, `cleaning_services_scheduling`, `customer_feedback_and_complaints`,            │
# │ `facility_management_issues`                                                                                    │
# │ Your complete message should be a valid json string that can be read directly and only contain the keys         │
# │ mentioned in the list above. Never enclose it in ```json...```, no newlines, no unnessacary whitespaces.        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ## Push Local Dataset to Object Store and Create Artifact

# %%
artifact, dataset_path = upload_dataset(
    secret=dataset_secret,
    local_path=dataset_local_path,
    remote_path=dataset_remote_path,
    expected_keys=base_template.placeholders,
    scenario=scenario,
    overwrite=True,
    allow_bucket_root=True
)

print(f"Dataset uploaded to {artifact.url}/{dataset_path} -> Artifact ID: {artifact.id}")
# Out:
# Dataset uploaded to ai://default/datasets/facility-train.json -> Artifact ID: d83a0795-2808-4529-99af-88d2d2cd311f

# %% [markdown]
# ## Create Prompt Optimizer Config

# %%
configuration_id = create_config(
    metric=metric,
    custom_metric_id=custom_metric_id,
    reference_model=reference_model,
    targets=targets,
    dataset_path=dataset_path,
    scenario=scenario,
    prompt=prompt,
    artifact_id=artifact.id,
    model_params=model_params,
    variable_mapping=variable_mapping,
    prototype_mode=prototype_mode,
    field_evaluation_metrics=field_evaluation_metrics,
)

# %% [markdown]
# ## Start Prompt Optimizer

# %%
response = client.ai_core_client.execution.create(
    configuration_id = configuration_id,
    resource_group = resource_group
)

execution_id = response.id
print('Execution started with ID:', execution_id)
# Out:
# Execution started with ID: e1aa8c6dee7b0fbb

# %% [markdown]
# ## Wait for Completion

# %%
import time
import sys

def wait_for_completion(execution_id, timeout=3600, initial_interval=120, pending_interval=40):
    """Poll until execution reaches COMPLETED or a terminal status."""
    start = time.time()
    last_status = None
    interval = initial_interval
    while time.time() - start < timeout:
        response = client.ai_core_client.execution.get(
            execution_id="e1aa8c6dee7b0fbb", resource_group=resource_group, select="status"
        )
        status = response.status.name
        elapsed = int(time.time() - start)
        if status != last_status:
            print(f"[{elapsed}s] Status: {status}", flush=True)
            last_status = status
        if status == "COMPLETED":
            print("Optimization completed successfully.", flush=True)
            return
        elif status in {"DEAD", "STOPPED", "STOPPING"}:
            print(f"Execution ended with status: {status}. Use the debug cells below to investigate.", flush=True)
            return
        elif status == "UNKNOWN":
            interval = initial_interval
        else:
            interval = pending_interval
        time.sleep(interval)
    print(f"Timed out after {timeout}s. Last status: {status}", flush=True)

wait_for_completion(execution_id)
# Out:
# [2s] Status: RUNNING
# [1277s] Status: COMPLETED
# Optimization completed successfully.

# %% [markdown]
# ## View Results

# %%
fetch_and_print_results(execution_id)
# Out:
#                          Score Summary
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┓
# ┃ Model              ┃ Baseline ┃  Pre  ┃ Post  ┃ Improvement ┃
# ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━┩
# │ gpt-4o:2024-08-06  │  0.782   │   –   │   –   │      –      │
# │ gemini-2.5-pro:001 │    –     │ 0.755 │ 0.873 │  ▲ +15.6%   │
# └────────────────────┴──────────┴───────┴───────┴─────────────┘
#                                  Evaluation Details — gpt-4o:2024-08-06
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metric       ┃                                                                              Baseline ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ score        │                                                                                 0.782 │
# │ total        │                                                                                   200 │
# │ n_correct    │                                                                                    97 │
# │ pct_correct  │                                                                                 0.485 │
# │ field_scores │ {'urgency': 0.795, 'sentiment': 0.575, 'categories.emergency_repair_services': 0.975} │
# └──────────────┴───────────────────────────────────────────────────────────────────────────────────────┘
#     Token Consumption —
#      gpt-4o:2024-08-06
# ┏━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Metric        ┃   Value ┃
# ┡━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ input_tokens  │ 131,812 │
# │ output_tokens │  19,200 │
# │ num_requests  │     200 │
# └───────────────┴─────────┘
#                                       Evaluation Details — gemini-2.5-pro:001
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metric       ┃                                             Pre ┃                                           Post ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ score        │                                           0.755 │                                          0.873 │
# │ total        │                                             200 │                                            200 │
# │ n_correct    │                                              77 │                                            133 │
# │ pct_correct  │                                           0.385 │                                          0.665 │
# │ field_scores │            {'urgency': 0.82, 'sentiment': 0.46, │         {'urgency': 0.915, 'sentiment': 0.715, │
# │              │  'categories.emergency_repair_services': 0.985} │  'categories.emergency_repair_services': 0.99} │
# └──────────────┴─────────────────────────────────────────────────┴────────────────────────────────────────────────┘
#                                       Token Consumption — gemini-2.5-pro:001
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metric                  ┃                                                                                 Value ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ provider_request_counts │ [{'provider': {'model_name': 'gpt-5', 'model_params': {'reasoning_effort': 'medium'}, │
# │                         │        'model_version': '2025-08-07'}, 'num_requests': 36, 'purpose': 'optimization', │
# │                         │         'input_tokens': 327313, 'output_tokens': 167382}, {'provider': {'model_name': │
# │                         │  'gemini-2.5-pro', 'model_params': {}, 'model_version': '001'}, 'num_requests': 1660, │
# │                         │ 'purpose': 'target', 'input_tokens': 3152372, 'output_tokens': 2176504}, {'provider': │
# │                         │          {'model_name': 'gpt-4o', 'model_params': {}, 'model_version': '2024-08-06'}, │
# │                         │    'num_requests': 200, 'purpose': 'origin', 'input_tokens': 131812, 'output_tokens': │
# │                         │     19200}, {'provider': {'model_name': 'gpt-5', 'model_params': {}, 'model_version': │
# │                         │     'latest'}, 'num_requests': 1860, 'purpose': 'evaluation', 'input_tokens': 130200, │
# │                         │                'output_tokens': 57580}, {'provider': {'model_name': 'gemini-2.5-pro', │
# │                         │           'model_params': {}, 'model_version': '001'}, 'num_requests': 32, 'purpose': │
# │                         │                     'optimization', 'input_tokens': 317197, 'output_tokens': 105004}] │
# └─────────────────────────┴───────────────────────────────────────────────────────────────────────────────────────┘
# ╭──────────────────────────────── System Message - Optimized — gemini-2.5-pro:001 ────────────────────────────────╮
# │ You are an information extraction and classification engine for support message triage. Read a single message   │
# │ and output a compact, strictly valid JSON object with exactly three keys: urgency, sentiment, categories. Do    │
# │ not output any explanations or text outside the JSON.                                                           │
# │                                                                                                                 │
# │ Output constraints:                                                                                             │
# │ - Output exactly one single-line JSON object with keys in this exact order: "urgency","sentiment","categories". │
# │ Treat this order as authoritative regardless of any examples you may have seen.                                 │
# │ - Produce minified JSON (no unnecessary spaces) on a single line. If minor whitespace occurs, the JSON must     │
# │ still be a single line and strictly valid; never include any extra text outside the JSON object.                │
# │ - Use lowercase strings for labels.                                                                             │
# │ - Use JSON booleans true/false (not True/False).                                                                │
# │ - Double-quote all JSON keys and string values; no trailing commas; no extra keys; single line.                 │
# │ - Inside "categories", include all category keys, each set to true or false, in this exact order:               │
# │ emergency_repair_services, routine_maintenance_requests, quality_and_safety_concerns,                           │
# │ specialized_cleaning_services, general_inquiries, sustainability_and_environmental_practices,                   │
# │ training_and_support_requests, cleaning_services_scheduling, customer_feedback_and_complaints,                  │
# │ facility_management_issues.                                                                                     │
# │                                                                                                                 │
# │ Decision rules:                                                                                                 │
# │ - Urgency:                                                                                                      │
# │   - high: Explicit urgency/time-critical cues (e.g., urgent, immediately, asap, critical, emergency), safety    │
# │ hazards, risks to people/property, outages, or critical failures. Heuristics: building-wide or mission-critical │
# │ system failures affecting occupants (e.g., HVAC failure during extreme weather), active hazards (e.g., leak,    │
# │ fire, electrical short, gas smell), contamination/spill, and outage-related language.                           │
# │   - medium: Time-sensitive but not critical; issues needing attention soon or ongoing problems without          │
# │ emergency cues. Default for routine maintenance or service requests unless explicitly “no rush” or purely       │
# │ informational.                                                                                                  │
# │   - low: Informational requests with no time pressure or messages explicitly indicating low/no urgency.         │
# │ - Sentiment:                                                                                                    │
# │   - positive: Primary purpose is praise/appreciation/compliments without complaints. This can co-occur with a   │
# │ service request if the message contains sustained praise and no dissatisfaction.                                │
# │   - neutral: Default for requests/inquiries or factual tone without explicit dissatisfaction; mixed tone        │
# │ without clear complaint.                                                                                        │
# │   - negative: Requires clear expressions of dissatisfaction or strong negative language about past service      │
# │ responsiveness/outcomes (e.g., unacceptable, poor service, not satisfied, subpar, unresolved issues). Do not    │
# │ let urgency alone determine sentiment; routine polite requests (even urgent) should usually be neutral.         │
# │ - Category definitions and disambiguation (set multiple true if clearly applicable, but prefer the minimal      │
# │ necessary set; prefer specific tags over general_inquiries unless the primary intent is to request information  │
# │ about services):                                                                                                │
# │   - emergency_repair_services: Active hazards, critical failures, or outages causing immediate danger or        │
# │ requiring urgent dispatch. Use for ongoing incidents or critical failures impacting occupants/operations.       │
# │   - routine_maintenance_requests: Non-urgent maintenance/repair needs, routine checks, or malfunctions that are │
# │ inconvenient but not emergencies. Do not set for mere references to past issues without a current service       │
# │ request.                                                                                                        │
# │   - quality_and_safety_concerns: Safety or service-quality issues requiring investigation/corrective action but │
# │ not immediate emergencies (e.g., protocol lapses, compliance issues, unsafe practices without an ongoing        │
# │ incident). If both this and emergency seem plausible, choose emergency only for ongoing hazards/critical        │
# │ failures; otherwise use quality_and_safety_concerns (urgency may still be high).                                │
# │   - specialized_cleaning_services: Deep/specialized cleaning (e.g., deep clean, carpet care,                    │
# │ post-construction).                                                                                             │
# │   - general_inquiries: Information-seeking about services, documentation, pricing, capabilities. May co-occur   │
# │ with specific tags when the primary intent is to gather information about services (even if specific domains    │
# │ like emergency or sustainability are mentioned). Do not set for operational service requests where the user     │
# │ asks for work to be performed rather than information.                                                          │
# │   - sustainability_and_environmental_practices: Eco-friendly products/practices, energy efficiency,             │
# │ environmental impact. Set only when sustainability/energy efficiency is a meaningful focus, not a passing       │
# │ mention.                                                                                                        │
# │   - training_and_support_requests: Requests for training, guidance, best practices, workshops, or support       │
# │ sessions.                                                                                                       │
# │   - cleaning_services_scheduling: Date/time coordination or rescheduling for cleaning, when                     │
# │ scheduling/rescheduling is the primary intent (explicit schedule/reschedule language or specific dates/times).  │
# │   - customer_feedback_and_complaints: Explicit evaluative feedback on prior service quality or outcomes         │
# │ (complaints or praise about past experiences/responsiveness). Only set when the primary intent is evaluative    │
# │ feedback; do not set for incidental politeness or appreciation that precedes a request.                         │
# │   - facility_management_issues: Systemic/program-level facility management topics (e.g., KPIs, oversight,       │
# │ policies, integration), not single incidents.                                                                   │
# │                                                                                                                 │
# │ Heuristic cues (non-exhaustive) to reduce misses: urgent, immediately, asap, critical, emergency, hazard, risk, │
# │ outage, leak, fire, broken, failure, unsafe, contamination, spill; schedule, reschedule, booking conflict;      │
# │ training, workshop, session; policy, KPI, oversight; deep clean, carpet, post-construction; eco-friendly,       │
# │ energy efficiency.                                                                                              │
# │                                                                                                                 │
# │ Reasoning: Analyze intent, urgency cues, sentiment tone, and domain. Resolve overlaps using the disambiguation  │
# │ rules above. Think through these steps internally but only output the final JSON.                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────── User Message - Optimized — gemini-2.5-pro:001 ─────────────────────────────────╮
# │ # Instructions                                                                                                  │
# │ - Read the message in the Context section and classify it.                                                      │
# │ - Output a single-line JSON object with exactly these keys in this order: "urgency","sentiment","categories".   │
# │ Treat this order as authoritative.                                                                              │
# │ - Produce minified JSON (no unnecessary spaces) on a single line. Avoid extra whitespace; ensure strictly valid │
# │ JSON. Output only the JSON object. No explanations, no extra text, no code fences, no newlines.                 │
# │ - Use only the labels specified; all labels must be lowercase.                                                  │
# │ - In "categories", include all category keys listed below, each set to a JSON boolean true/false. Select the    │
# │ minimal set of categories that clearly apply. Prefer specific tags over general_inquiries unless the primary    │
# │ intent is an information request about services; in such cases, general_inquiries may co-occur with specific    │
# │ tags.                                                                                                           │
# │ - Apply the decision rules consistently with the system prompt.                                                 │
# │ - Use only the text inside the <message> tags.                                                                  │
# │                                                                                                                 │
# │ ## Urgency rules                                                                                                │
# │ - high: Explicit urgency/time-critical cues (e.g., urgent, immediately, asap, critical, emergency), safety      │
# │ hazards, risks to people/property, outages, or critical failures. Heuristics: building-wide or mission-critical │
# │ system failures affecting occupants (e.g., HVAC failure during extreme weather), active hazards (leak, fire,    │
# │ electrical short, gas smell), contamination/spill.                                                              │
# │ - medium: Time-sensitive but not critical; issues needing attention soon or ongoing problems without emergency  │
# │ cues. Default for routine maintenance/service requests unless explicitly "no rush" or purely informational.     │
# │ - low: Informational requests with no time pressure or messages explicitly indicating low/no urgency.           │
# │                                                                                                                 │
# │ ## Sentiment rules                                                                                              │
# │ - positive: Primary purpose is praise/appreciation/compliments without complaints. Can still be positive if a   │
# │ service request accompanies sustained praise with no dissatisfaction.                                           │
# │ - neutral: Default for requests/inquiries or factual tone without explicit dissatisfaction; mixed tone without  │
# │ a clear complaint.                                                                                              │
# │ - negative: Only when there are clear expressions of dissatisfaction or strong negative language about past     │
# │ service responsiveness/outcomes (e.g., unacceptable, poor service, not satisfied, subpar, unresolved issues).   │
# │ Do not let urgency alone determine sentiment; routine polite requests (even urgent) should usually be neutral.  │
# │                                                                                                                 │
# │ ## Category disambiguation and constraints                                                                      │
# │ - emergency_repair_services vs. quality_and_safety_concerns: Reserve emergency_repair_services for active       │
# │ hazards/critical failures/outages needing immediate dispatch (e.g., outage, leak, fire, unsafe conditions).     │
# │ Classify protocol/quality lapses without an ongoing incident under quality_and_safety_concerns (urgency may     │
# │ still be high).                                                                                                 │
# │ - routine_maintenance_requests: Use for non-urgent maintenance/repair needs or malfunctions that are            │
# │ inconvenient but not emergencies. Do not set solely for references to past issues without a current request.    │
# │ - cleaning_services_scheduling: Only when date/time coordination or rescheduling for cleaning is the primary    │
# │ focus (explicit schedule/reschedule language or specific dates/times).                                          │
# │ - customer_feedback_and_complaints: Only for explicit evaluative feedback on prior service quality/outcomes     │
# │ (complaints/praise). Do not set for generic appreciation or courtesy preceding a request.                       │
# │ - facility_management_issues: Only for systemic/program-level topics (e.g., KPIs, oversight, policies,          │
# │ integration), not single incidents.                                                                             │
# │ - sustainability_and_environmental_practices: Set only when eco-friendly practices or energy efficiency are     │
# │ substantive foci, not incidental mentions.                                                                      │
# │ - general_inquiries: Use for information-seeking about services, documentation, pricing, or capabilities. May   │
# │ co-occur with specific tags when the primary intent is to gather information about services; omit it when the   │
# │ message is an operational service request.                                                                      │
# │                                                                                                                 │
# │ ## Sample Phrases (non-exhaustive cues)                                                                         │
# │ - Urgency/high: urgent, asap, immediately, emergency, critical, outage, hazard, leak, fire, unsafe, broken,     │
# │ failure, contamination, spill.                                                                                  │
# │ - Scheduling: schedule, reschedule, booking, availability, date/time.                                           │
# │ - Training/support: training, workshop, session, guidance, best practices.                                      │
# │ - Specialized cleaning: deep clean, carpet care, post-construction, detailed cleaning.                          │
# │ - Sustainability: eco-friendly, green products, energy efficiency, reduce environmental impact.                 │
# │ - Facility management issues: policy, KPI, oversight, program, integration.                                     │
# │ - Feedback/complaints: dissatisfied, unacceptable, poor service, not satisfied, unresolved.                     │
# │                                                                                                                 │
# │ # Reasoning Steps                                                                                               │
# │ 1) Identify the primary intent and domain-specific cues.                                                        │
# │ 2) Scan for emergency/time-critical cues and safety-risk language (e.g., emergency, asap, critical, outage,     │
# │ leak, fire, unsafe).                                                                                            │
# │ 3) Determine urgency using the rules above; default routine maintenance/service requests to medium unless       │
# │ explicitly low or truly high.                                                                                   │
# │ 4) Determine sentiment: default neutral for requests/inquiries; use positive only if primarily praise; use      │
# │ negative only with explicit dissatisfaction/strong negative language.                                           │
# │ 5) Select categories using the minimal set that clearly applies. Prefer specific tags over general_inquiries    │
# │ unless the primary intent is informational; allow co-occurrence in that case.                                   │
# │ 6) Explicit check: Only set customer_feedback_and_complaints if the message’s primary intent is evaluative      │
# │ feedback on past service responsiveness/outcomes.                                                               │
# │ 7) Output validation checklist: verify exactly three top-level keys in the required order; include all category │
# │ keys in the required order; lowercase labels; JSON booleans true/false; single-line JSON; minified (no          │
# │ unnecessary spaces).                                                                                            │
# │                                                                                                                 │
# │ # Output Format                                                                                                 │
# │ - JSON object with keys in this order: "urgency","sentiment","categories".                                      │
# │ - All strings lowercase; JSON booleans true/false; double-quoted keys/strings; no trailing commas; single line; │
# │ minified JSON with no unnecessary spaces.                                                                       │
# │ - Include all category keys inside "categories" in this order: emergency_repair_services,                       │
# │ routine_maintenance_requests, quality_and_safety_concerns, specialized_cleaning_services, general_inquiries,    │
# │ sustainability_and_environmental_practices, training_and_support_requests, cleaning_services_scheduling,        │
# │ customer_feedback_and_complaints, facility_management_issues.                                                   │
# │                                                                                                                 │
# │ # Context                                                                                                       │
# │ Using only the text inside these tags:                                                                          │
# │ <message>                                                                                                       │
# │ {{?input}}                                                                                                      │
# │ </message>                                                                                                      │
# │                                                                                                                 │
# │ # Final instructions                                                                                            │
# │ Output only the final single-line minified JSON object with exactly the keys and ordering specified above. Use  │
# │ lowercase labels and JSON booleans true/false. No explanations, no extra text, no newlines.                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
